# %%
import ollama

# %%
message = ollama.chat(model="gemma4:12b-mlx", messages=[{"role": "user", "content": "hi"}], think=False)

# %%
message.message.content
# Out:
# 'Hello! How can I help you today?'
